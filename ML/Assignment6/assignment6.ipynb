# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sales_data_sample.csv', encoding='unicode_escape')
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
x = df[['SALES', 'QUANTITYORDERED']].dropna()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
from sklearn.cluster import KMeans
wcss = [] # within-cluster sum of squares
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(x_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Fit K-Means with the optimal number of clusters (choose based on elbow plot)
optimal_k = 3  # Replace with the value observed from the elbow plot
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
df['Cluster'] = kmeans.fit_predict(x_scaled)

# %%
print(df[['SALES', 'QUANTITYORDERED', 'Cluster']])
# Out:
#         SALES  QUANTITYORDERED  Cluster
# 0     2871.00               30        0
# 1     2765.90               34        1
# 2     3884.34               41        1
# 3     3746.70               45        1
# 4     5205.27               49        2
# ...       ...              ...      ...
# 2818  2244.40               20        0
# 2819  3978.51               29        0
# 2820  5417.57               43        2
# 2821  2116.16               34        0
# 2822  3079.44               47        1
#
# [2823 rows x 3 columns]
